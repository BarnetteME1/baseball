# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
batting = pd.read_csv('baseball_csv_files/batting.csv')

# %%
batting.columns.values
# Out:
# array(['player_id', 'year', 'stint', 'team_id', 'league_id', 'g', 'ab',
#        'r', 'h', 'double', 'triple', 'hr', 'rbi', 'sb', 'cs', 'bb', 'so',
#        'ibb', 'hbp', 'sh', 'sf', 'g_idp'], dtype=object)

# %%
batting.plot(kind='scatter', x='hr', y='h', figsize=(20,10), xlim=(0,75), ylim=(0, 300))
