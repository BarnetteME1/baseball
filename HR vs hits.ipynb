# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
batting = pd.read_csv('baseball_csv_files/batting.csv')

# %%
batting = batting[batting.ab > 50]

# %%
batting.plot(kind='scatter', x='h', y='hr', figsize=(20,10), xlim=(-1,275), ylim=(-1, 75))
