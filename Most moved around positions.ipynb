# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
appearences = pd.read_csv('baseball_csv_files/appearances.csv')

# %%
appearences.sort_values(by=['player_id', 'year']).head(15)
# Out:
#        year team_id league_id  player_id  g_all   gs  g_batting  g_defense  \
# 85713  2004     SFN        NL  aardsda01   11.0  0.0         11       11.0
# 87495  2006     CHN        NL  aardsda01   45.0  0.0         43       45.0
# 88832  2007     CHA        AL  aardsda01   25.0  0.0          2       25.0
# 90166  2008     BOS        AL  aardsda01   47.0  0.0          5       47.0
# 92486  2009     SEA        AL  aardsda01   73.0  0.0          3       73.0
# 93852  2010     SEA        AL  aardsda01   53.0  0.0          4       53.0
# 96207  2012     NYA        AL  aardsda01    1.0  0.0          0        1.0
# 97582  2013     NYN        NL  aardsda01   43.0  0.0         41       43.0
# 99466  2015     ATL        NL  aardsda01   33.0  0.0         30       33.0
# 37137  1954     ML1        NL  aaronha01  122.0  NaN        122      122.0
# 37803  1955     ML1        NL  aaronha01  153.0  NaN        153      153.0
# ...

# %%
appearences.groupby('player_id').sum()
# Out:
#             year   g_all      gs  g_batting  g_defense  g_p  g_c  g_1b  g_2b  \
# player_id
# aardsda01  18084   331.0     0.0        139      331.0  331    0     0     0
# aaronha01  45195  3298.0   288.0       3298     3057.0    0    0   210    43
# aaronto01  13768   437.0     NaN        437      437.0    0    0   232     7
# aasedo01   25786   448.0     0.0         81      448.0  448    0     0     0
# abadan01    6010    15.0     4.0         15        9.0    0    0     8     0
# abadfe01   12075   258.0     6.0        131      258.0  258    0     0     0
# abadijo01   3750    12.0     NaN         12       12.0    0    0    12     0
# abbated01  19051   855.0     NaN        855      855.0    0    0     0   419
# abbeybe01  11365    79.0     NaN         79       79.0   79    0     0     0
# abbeych01   9475   452.0     NaN        452      452.0    1    0     0     0
# abbotda01   1890     3.0     NaN          3        3.0    3    0     0     0
# ...
